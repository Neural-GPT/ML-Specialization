# %%
import numpy as np

# %%
x=np.array([5,4,7,8,2])
w=3
b=7
y=np.array([25,20,32,37,19])
def compute_cost(w,b):
  cost=0
  m=len(x)
  total_cost=np.sum((((w*x)+ b)-y)**2)/(2*m)
  squared_errors=((((w*x)+ b)-y)**2)
  print("Squared erros: ",squared_errors)
  return total_cost

# %%
compute_cost(3,7)
# Out:
# Squared erros:  [ 9  1 16 36 36]
# np.float64(9.8)
