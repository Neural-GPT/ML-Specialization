# %%
import numpy as np
x=np.random.uniform(-150,150,100000000)
w=np.random.uniform(-7,10,100000000)
b=np.random.uniform(-10,100,1)+

# %%
predict=0
for n in range(len(x)):
  predict+=w[n]*x[n]
predict+b
#took 51 seconds!
# Out:
# array([-12749757.53345832])

# %%
pred=np.dot(x,w) + b
pred+b
#exexuted instantly
# Out:
# array([-12749705.51622307])

# %%
import numpy as np
a=np.random.uniform(-7,-10,5)
a
# Out:
# array([-8.44734746, -8.36558241, -9.21072619, -8.27055624, -7.68513127])
